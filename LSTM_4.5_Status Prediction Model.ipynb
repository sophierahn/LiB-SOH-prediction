# %%
#Importing Libraries
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
import random
import matplotlib.pyplot as plt
import csv

# %%
dfv = pd.read_csv("C:\\Users\\sophi\\VS Code Projects\\LiB-SOH-prediction\\Nasa Battery Data\\Battery 5\\Discharge cycle\\Padded and Resampled\\NoisyInputData2.csv")
dft = pd.read_csv("C:\\Users\\sophi\\VS Code Projects\\LiB-SOH-prediction\\Nasa Battery Data\\Battery 5\\Discharge cycle\\Padded and Resampled\\NoisyInputTempData2.csv")

# %%
dfv.reset_index(inplace=True, drop=True)
dft.reset_index(inplace=True, drop=True)
#df = pd.concat([df1,df2],axis=1,join='inner')
dfv

# %%
scaler = MinMaxScaler()

#Extracting Voltage
trainXv = dfv.drop(columns=["y"])
trainy = dfv['y'] 
trainXv = trainXv.to_numpy()
trainy = trainy.to_numpy()
rows, columns = trainXv.shape
trainy = trainy.reshape(rows,1)
Xv_train = scaler.fit_transform(trainXv)

#Extracting Temperature
trainXt = dft.drop(columns=["y"])
trainXt = trainXt.to_numpy()
Xt_train = scaler.fit_transform(trainXt)

#trainX = np.empty((1,2), dtype=np.array)

#trainX[0,0] = trainXv
#trainX[0,1] = trainXt

Xn_train = np.array([Xv_train,Xt_train])



#Normalizing
#Xn_train = scaler.fit_transform(trainXv)
yn_train = scaler.fit_transform(trainy)

# %%
#Reshaping
Xn_train = Xn_train.reshape(rows, 2, columns)
X_train, X_test, y_train, y_test = train_test_split(Xn_train,yn_train , test_size=0.10)
test_rows,foo, test_columns = X_test.shape

# %%
f = open('Nasa Battery Data\\Battery 5\\Discharge cycle\\Padded and Resampled\\RefactoredData3.csv', 'w', newline='')

# create the csv writer
writer = csv.writer(f)
for i in Xn_train:
    writer.writerow(i)
f.close()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(LSTM(100, activation='tanh', input_shape=(1,222), return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(LSTM(100, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(LSTM(64, activation='tanh', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(yn_train.shape[1]))

tf.keras.optimizers.Adam(
    learning_rate=0.001,
    name='Adam')

model.compile(optimizer='Adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 1, 100)            129200
#
#  dropout_10 (Dropout)        (None, 1, 100)            0
#
#  dense_8 (Dense)             (None, 1, 64)             6464
#
#  lstm_11 (LSTM)              (None, 1, 100)            66000
#
#  dropout_11 (Dropout)        (None, 1, 100)            0
#
#  dense_9 (Dense)             (None, 1, 64)             6464
#
#  lstm_12 (LSTM)              (None, 64)                33024
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_10 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 241,217
# Trainable params: 241,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fitting the model to X_train and y_train dataset, and 100 epochs and saving it into history
history = model.fit(X_train,y_train, epochs=100,batch_size=5)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 12s 8ms/step - loss: 0.0534
# Epoch 2/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0086
# Epoch 3/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0053
# Epoch 4/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0068
# Epoch 5/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0044
# Epoch 6/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0036
# Epoch 7/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0042
# Epoch 8/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0044
# Epoch 9/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0033
# Epoch 10/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0041
# Epoch 11/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0041
# Epoch 12/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0025
# Epoch 13/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0025
# Epoch 14/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 15/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 16/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0030
# Epoch 17/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 18/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 19/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0027
# Epoch 20/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0029
# Epoch 21/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0031
# Epoch 22/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 23/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0026
# Epoch 24/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0035
# Epoch 25/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0025
# Epoch 26/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 27/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 28/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 29/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0023
# Epoch 30/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0021
# Epoch 31/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0021
# Epoch 32/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 33/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0031
# Epoch 34/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0025
# Epoch 35/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 36/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 37/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 38/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 39/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0034
# Epoch 40/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 41/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 42/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 43/100
# 56/56 [==============================] - 2s 42ms/step - loss: 0.0022
# Epoch 44/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 45/100
# 56/56 [==============================] - 1s 26ms/step - loss: 0.0021
# Epoch 46/100
# 56/56 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 47/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0020
# Epoch 48/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 49/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 50/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 51/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 52/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 53/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 54/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 55/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 56/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 57/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0022
# Epoch 58/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0019
# Epoch 59/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0018
# Epoch 60/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 61/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 62/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 63/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 64/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 65/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 66/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0018
# Epoch 67/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 68/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0017
# Epoch 69/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 70/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 71/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 72/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 73/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 74/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0019
# Epoch 75/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 76/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 77/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 78/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0021
# Epoch 79/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 80/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 81/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 82/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 83/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0015
# Epoch 84/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0018
# Epoch 85/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 86/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 87/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 88/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 89/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 90/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 91/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 92/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 93/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0013
# Epoch 94/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0013
# Epoch 95/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 96/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 97/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 98/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0015
# Epoch 99/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 100/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0014

# %%
# Using function to get loss history
training_loss = history.history['loss']

# Code for counting the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.legend(['Training Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(test_rows,1)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025A2848F0D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step

# %%
yd_pred = scaler.inverse_transform(y_pred)
y_error = y_test - yd_pred
df5 = pd.DataFrame(y_test)
df6 = pd.DataFrame(yd_pred)
df7 = pd.DataFrame(y_error)
DFF = pd.concat([df5,df6,df7],axis=1,join='inner')
DFF
# Out:
#            0         0         0
# 0   0.560793  1.599848 -1.039056
# 1   0.366655  1.494723 -1.128068
# 2   0.735565  1.691937 -0.956372
# 3   0.118185  1.357406 -1.239221
# 4   0.292941  1.446597 -1.153656
# 5   0.504851  1.565639 -1.060788
# 6   0.798307  1.739347 -0.941040
# 7   0.154268  1.375867 -1.221599
# 8   0.228416  1.416733 -1.188317
# 9   0.478053  1.544247 -1.066193
# 10  0.961616  1.811216 -0.849600
# 11  0.072389  1.336186 -1.263797
# 12  0.145960  1.368422 -1.222463
# 13  0.982145  1.815033 -0.832888
# 14  0.469632  1.543670 -1.074038
# 15  0.173380  1.391074 -1.217695
# 16  0.606786  1.627190 -1.020404
# 17  0.182471  1.392705 -1.210235
# 18  0.037894  1.324735 -1.286841
# 19  0.018665  1.310162 -1.291497
# 20  0.905264  1.801329 -0.896065
# 21  0.983373  1.815499 -0.832126
# 22  0.028043  1.314017 -1.285974
# 23  0.551920  1.593203 -1.041283
# 24  0.789003  1.730674 -0.941671
# 25  0.063654  1.332579 -1.268924
# 26  0.991767  1.811347 -0.819580
# 27  0.228416  1.415259 -1.186843
# 28  0.035751  1.328399 -1.292648
# 29  0.238066  1.411945 -1.173879
# 30  0.090572  1.340195 -1.249622

# %%
from sklearn.metrics import mean_absolute_error
print('MAE for y: %.3f' % mean_absolute_error(y_test, yd_pred))
# Out:
# MAE for y: 1.105

# %% [markdown]
# Data plotting
# pd.read_csv("C:\\Users\\sophi\\VS Code Projects\\LiB-SOH-prediction\\Nasa Battery Data\\Battery 5\\Discharge cycle\\Padded and Resampled\\NoisyInputData2.csv")

# %%
DFF.plot()
plt.show()

# %%
x_axis 
plt.scatter(y_test)
plt.xlabel('Time step')
plt.ylabel('Capacity')
